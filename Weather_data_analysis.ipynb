# %% [markdown]
# <a href="https://colab.research.google.com/github/VivekMuraleedharanGit/Notebooks/blob/master/Weather_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Weather data set
#
# Data set consisits of time series data with per hour information at perticular Dwe point temparature,Relative Humidity,Wind speed,Visibility,Pressure and condition

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Udemy bootcamp/1. Weather Data.csv')

# %%
data.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
#weather is categorical feature will see the unique values in that column

data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#count to check the values in dataset
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
#Null values in the data set
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
#there is no null values on the dataset

# %%
#1.find all unique"wind speed' values in data

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
#2. Find the number of times when the 'Weather is exactly clear'
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0  1/1/2012 0:00    -1.8              -3.9  ...            8.0     101.24      Fog
# 1  1/1/2012 1:00    -1.8              -3.7  ...            8.0     101.24      Fog
#
# [2 rows x 8 columns]

# %%
data[data['Weather']=='Clear']
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 67      1/3/2012 19:00   -16.9  ...     101.74    Clear
# 114     1/5/2012 18:00    -7.1  ...     100.71    Clear
# 115     1/5/2012 19:00    -9.2  ...     100.80    Clear
# 116     1/5/2012 20:00    -9.8  ...     100.83    Clear
# 117     1/5/2012 21:00    -9.0  ...     100.83    Clear
# ...                ...     ...  ...        ...      ...
# 8646   12/26/2012 6:00   -13.4  ...     102.47    Clear
# 8698  12/28/2012 10:00    -6.1  ...     101.27    Clear
# 8713   12/29/2012 1:00   -11.9  ...     101.31    Clear
# 8714   12/29/2012 2:00   -11.8  ...     101.33    Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52    Clear
#
# [1326 rows x 8 columns]

# %%
data[data['Weather']=='Clear'].count()
# Out:
# Date/Time           1326
# Temp_C              1326
# Dew Point Temp_C    1326
# Rel Hum_%           1326
# Wind Speed_km/h     1326
# Visibility_km       1326
# Press_kPa           1326
# Weather             1326
# dtype: int64

# %%
#3 find the number of times when the windspeed was 4km/h
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0  1/1/2012 0:00    -1.8              -3.9  ...            8.0     101.24      Fog
# 1  1/1/2012 1:00    -1.8              -3.7  ...            8.0     101.24      Fog
#
# [2 rows x 8 columns]

# %%
data['Wind Speed_km/h'].value_counts()
# Out:
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 63      1
# 54      1
# 70      1
# 83      1
# Name: Wind Speed_km/h, dtype: int64

# %%
data[data['Wind Speed_km/h']==4]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa       Weather
# 0        1/1/2012 0:00    -1.8  ...     101.24           Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24           Fog
# 96       1/5/2012 0:00    -8.8  ...     100.32          Snow
# 101      1/5/2012 5:00    -7.0  ...     100.19          Snow
# 146      1/7/2012 2:00    -8.1  ...     100.15        Cloudy
# ...                ...     ...  ...        ...           ...
# 8768   12/31/2012 8:00    -8.6  ...     101.14  Snow Showers
# 8769   12/31/2012 9:00    -8.1  ...     101.09          Snow
# 8770  12/31/2012 10:00    -7.4  ...     101.05      Snow,Fog
# 8772  12/31/2012 12:00    -5.8  ...     100.78          Snow
# 8773  12/31/2012 13:00    -4.6  ...     100.63          Snow
#
# [474 rows x 8 columns]

# %%
#5 rename the weather column in the data set to weather condition
data['WeatherCondition']= data['Weather']
data.head(2)
data.drop(columns=['WeatherCondition'],axis=1,inplace=True)

# %%
data.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
data.rename(columns={'Weather':'WeatherCondition'},inplace=True)

# %%
#what is the mean visibility

# %%
data.Visibility_km.mean()
# Out:
# 27.66444672131151

# %%
#What is the std deviation of the Pressure in this data

data.Press_kPa.std()
# Out:
# 0.8440047459486474

# %%
#what is the variance of relative humidity in the data

data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %%
data[data['WeatherCondition']=='Snow']
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  WeatherCondition
# 55       1/3/2012 7:00   -14.0  ...     100.95              Snow
# 84      1/4/2012 12:00   -13.7  ...     101.25              Snow
# 86      1/4/2012 14:00   -11.3  ...     100.97              Snow
# 87      1/4/2012 15:00   -10.2  ...     100.89              Snow
# 88      1/4/2012 16:00    -9.4  ...     100.79              Snow
# ...                ...     ...  ...        ...               ...
# 8779  12/31/2012 19:00     0.1  ...     100.13              Snow
# 8780  12/31/2012 20:00     0.2  ...     100.03              Snow
# 8781  12/31/2012 21:00    -0.5  ...      99.95              Snow
# 8782  12/31/2012 22:00    -0.2  ...      99.91              Snow
# 8783  12/31/2012 23:00     0.0  ...      99.89              Snow
#
# [390 rows x 8 columns]

# %%
#find all the instances where windspeed is above 24 and visibility is 25
data[(data['Wind Speed_km/h']==24)& (data['Visibility_km']==25)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  WeatherCondition
# 43      1/2/2012 19:00    -4.8  ...     100.00     Mostly Cloudy
# 44      1/2/2012 20:00    -5.6  ...     100.07      Snow Showers
# 52       1/3/2012 4:00   -12.6  ...     100.68            Cloudy
# 66      1/3/2012 18:00   -16.3  ...     101.64      Mainly Clear
# 67      1/3/2012 19:00   -16.9  ...     101.74             Clear
# ...                ...     ...  ...        ...               ...
# 8658  12/26/2012 18:00   -10.0  ...     102.14            Cloudy
# 8663  12/26/2012 23:00    -9.7  ...     101.61            Cloudy
# 8706  12/28/2012 18:00    -9.0  ...     101.37      Mainly Clear
# 8754  12/30/2012 18:00   -12.6  ...     101.36      Mainly Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52             Clear
#
# [107 rows x 8 columns]

# %%
#find the mean value of each column against each weather condition

data.groupby('WeatherCondition').mean()
# Out:
#                                             Temp_C  ...   Press_kPa
# WeatherCondition                                    ...
# Clear                                     6.825716  ...  101.587443
# Cloudy                                    7.970544  ...  100.911441
# Drizzle                                   7.353659  ...  100.435366
# Drizzle,Fog                               8.067500  ...  100.786625
# Drizzle,Ice Pellets,Fog                   0.400000  ...  100.790000
# Drizzle,Snow                              1.050000  ...  100.890000
# Drizzle,Snow,Fog                          0.693333  ...   99.281333
# Fog                                       4.303333  ...  101.184067
# Freezing Drizzle                         -5.657143  ...  100.202857
# Freezing Drizzle,Fog                     -2.533333  ...  100.441667
# Freezing Drizzle,Haze                    -5.433333  ...  100.316667
# Freezing Drizzle,Snow                    -5.109091  ...  100.520909
# ...

# %%
#What is the min and max value of each column against each weather condition

data.groupby('WeatherCondition').agg(['min','max'])
# Out:
#                                                 Date/Time  ... Press_kPa
#                                                       min  ...       max
# WeatherCondition                                           ...
# Clear                                      1/11/2012 1:00  ...    103.63
# Cloudy                                     1/1/2012 17:00  ...    103.65
# Drizzle                                   1/23/2012 21:00  ...    101.56
# Drizzle,Fog                               1/23/2012 20:00  ...    102.07
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00  ...    100.79
# Drizzle,Snow                             12/17/2012 15:00  ...    101.15
# Drizzle,Snow,Fog                         12/18/2012 21:00  ...    100.15
# Fog                                         1/1/2012 0:00  ...    103.04
# Freezing Drizzle                          1/13/2012 10:00  ...    101.02
# Freezing Drizzle,Fog                        1/1/2012 2:00  ...    101.27
# ...

# %%
#show all the records where weather is Fog

data[data.WeatherCondition=='Fog']
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  WeatherCondition
# 0        1/1/2012 0:00    -1.8  ...     101.24               Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24               Fog
# 4        1/1/2012 4:00    -1.5  ...     101.23               Fog
# 5        1/1/2012 5:00    -1.4  ...     101.27               Fog
# 6        1/1/2012 6:00    -1.5  ...     101.29               Fog
# ...                ...     ...  ...        ...               ...
# 8716   12/29/2012 4:00   -16.0  ...     101.25               Fog
# 8717   12/29/2012 5:00   -14.8  ...     101.25               Fog
# 8718   12/29/2012 6:00   -13.8  ...     101.25               Fog
# 8719   12/29/2012 7:00   -14.8  ...     101.22               Fog
# 8722  12/29/2012 10:00   -12.0  ...     101.15               Fog
#
# [150 rows x 8 columns]

# %%
#find all the instances where the weather condition is clear or visibility is above 40

data[(data.WeatherCondition=='Clear')|(data.Visibility_km>40)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  WeatherCondition
# 67      1/3/2012 19:00   -16.9  ...     101.74             Clear
# 106     1/5/2012 10:00    -6.0  ...     100.45      Mainly Clear
# 107     1/5/2012 11:00    -5.6  ...     100.41      Mainly Clear
# 108     1/5/2012 12:00    -4.7  ...     100.38      Mainly Clear
# 109     1/5/2012 13:00    -4.4  ...     100.40      Mainly Clear
# ...                ...     ...  ...        ...               ...
# 8749  12/30/2012 13:00   -12.4  ...     100.92     Mostly Cloudy
# 8750  12/30/2012 14:00   -11.8  ...     100.96      Mainly Clear
# 8751  12/30/2012 15:00   -11.3  ...     101.05      Mainly Clear
# 8752  12/30/2012 16:00   -11.4  ...     101.15      Mainly Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52             Clear
#
# [3027 rows x 8 columns]
